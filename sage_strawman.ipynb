# %% [markdown]
# # SAGE strawman

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys

# Replace 'my_script_folder' with the actual path to your folder in Google Drive
script_path = '/content/drive/MyDrive/SAGE/Github'
sys.path.insert(0, script_path)

# %%
from sage_strawman import *
# Out:
# Loaded 88 parameters from sage_params.csv
#
# Checking for required files...
#   OK: sage_single_asset_trajectory.csv
#   OK: sage_fleet_lifespans.csv
#
# Ready for analysis.
# ======================================================================
# SINGLE-ASSET SUMMARY
# ======================================================================
#
#   EOL time: 16.08 years (194 months)
#   Final SoH: 0.7000
#   q_cal: 0.0855 (28.5% of total loss)
#   q_cyc: 0.2145 (71.5% of total loss)
#   q_cal/q_cyc ratio: 0.40
#   Cumulative throughput: 16,947,629 kWh
#
# ======================================================================
# FLEET SUMMARY
# ======================================================================
#
#   Number of assets: 100
#   Mean lifespan: 14.55 years
#   Std lifespan: 1.12 years
#   Min lifespan: 12.46 years
#   Max lifespan: 17.03 years
#   Range: 4.57 years
#
# ======================================================================
# THROUGHPUT ACCUMULATION CHECK
# ======================================================================
#
#   Throughput rate: 1,035,667 kWh/year
#   Linearity R2: 0.989435
#   Max deviation from linear: 1,178,836 kWh
#
# ======================================================================
# DATA LOADED SUCCESSFULLY
# ======================================================================
#
# Variables available for Figure 5:
#   df_single  - Single-asset trajectory (monthly)
#   df_fleet   - Fleet lifespan data
# Loading SAGE data...
#   Single-asset: 194 rows, last time = 16.08 years
#   Fleet: 100 assets, lifespan range: 12.5-17.0 years
#
# Generating Figure 5 (TRUE SAGE EOL calibration)...
# Calibration (TRUE SAGE EOL): t_eol = 16.08 years, Q_eol = 16,947,629 kWh
# Figure saved to: /content/drive/MyDrive/SAGE/Figure_5_strawman_comparison.png
# ============================================================
# STRAWMAN COMPARISON STATISTICS (TRUE SAGE EOL)
# ============================================================
#
# Single-Asset Trajectory:
#   SAGE EOL time: 16.08 years
#   Throughput at EOL (grid-side): 16,947,629 kWh
#   Equivalent full cycles (grid-side): 3,390
#
# Linear Model Errors (0 to EOL):
#   Max overestimate: 2.16 %-points
#   Max underestimate: 0.00 %-points
#   Mean absolute error: 1.48 %-points
#
# Throughput Model Errors (0 to EOL):
#   Max overestimate: 0.08 %-points
#   Max underestimate: -0.96 %-points
#   Mean absolute error: 0.57 %-points
#
# Fleet Statistics (n=100):
#   SAGE mean lifespan: 14.55 years
#   SAGE std lifespan: 1.12 years
#   SAGE lifespan range: 12.5-17.0 years
#   Linear baseline predicted lifespan: 16.08 years (zero variance)
#   Throughput baseline predicted lifespan: 16.08 years (zero variance)
#
#   ** Key finding: Baseline models predict ZERO fleet variance **
#   ** SAGE captures 4.6 years of spread **
# ============================================================
# Done!
# Year: 8.0
# Linear error: 2.109493676315677
# Throughput error: -0.9149868644884873
