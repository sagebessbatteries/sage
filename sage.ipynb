# %% [markdown]
# # SAGE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys

# Replace 'my_script_folder' with the actual path to your folder in Google Drive
script_path = '/content/drive/MyDrive/SAGE/Github'
sys.path.insert(0, script_path)

# %%
from sage import *
# Out:
# Cell 0 loaded: require_global, hard_assert
# Cell 1: Loaded 89 parameters from /content/drive/MyDrive/SAGE/sage_params.csv
# Cell 2: Validated 89 parameters.
#    Constants: HOURS_PER_YEAR=8760, HOURS_PER_DAY=24, DAYS_PER_YEAR=365
#    Usable energy (BOL): 4500.0 kWh
#    Round-trip efficiency: 90.2%
#
#    === Temperature Configuration ===
#    OUTDOOR (drives prices):
#       Mean: 22.0degC, Seasonal: ±12.0degC, Diurnal: ±6.0degC
#       Range: ~4degC to ~40degC
#       Forecast error: σ=1.5degC
#    CONTAINER (drives degradation):
#       Baseline: 22.0degC (HVAC setpoint)
#       Attenuation: 8% of outdoor swing penetrates
#
#    Peak shifting: hot +3h, cold -1h
#    Spike base magnitude: $100/MWh
#    Export years for TwinBESS: 25
# Cell 3: Data structures defined.
#    SAGEEnvironmentStep: t_timestamp, p_market, p_forecast, T_ambient, T_amb_forecast, T_outdoor, T_outdoor_forecast, is_valid
#    SAGECommand: P_dispatch_kw
#    SAGEState: soc_true, soh_true, q_loss_cal, q_loss_cyc, T_cell, cumulative_kwh, t_index, t_cal_cumulative, soc_min, soc_max
#    soh_true bounds: [-1e-6, 1+1e-12] (Ticket C alignment)
# Cell 4: Environment generator defined (with HVAC-derived container temperature).
#    generate_sage_environment(n_hours, sp, seed, verbose)
#    Container model: T_ambient = container_baseline + container_attenuation × (T_outdoor - T_outdoor_mean)
#    container_attenuation=0 ---> perfect HVAC; container_attenuation=1 ---> no HVAC
#    Spike magnitude now parameterized: spike_base_magnitude from CSV
# Cell 5: Physics engine defined.
#    Ticket A: dur_hours (int) via ValueError (not hard_assert)
#    Ticket B: SOC window well-ordering guard each timestep
#    Ticket C: SoH bounded; raises if nonphysical
#    Ticket D: K_T calibration comment (calibrated_temp_rise_c4 = ΔT at P_dis)
#    Ticket E: compute_thermal_limit returns inf when eta ~ 1
#    Ticket F: daily SOC reset annotated and guarded
#    Ticket G: compute_cycle_aging_increment uses cap_now (not cap_nom)
#    No B1: SOC clamped only after discharge (manuscript semantics)
#    Option B: block clock paused on invalid env hours
#    Post-discharge: discharge_drift_tol=1e-3 for intra-block parameter drift
#    Option B: soc_min/soc_max logged in every SAGEState
#    Finiteness guards: Arrhenius T_K, soc_term, thermal T_ambient, K_T eta<1
# ============================================================
# SAGE Physics Unit Tests
# ============================================================
#
# [1] Arrhenius Factor
# ----------------------------------------
#    PASS: Factor = 1.0 at reference temperature
#    PASS: Factor > 1.0 at T > T_ref
#    PASS: Factor < 1.0 at T < T_ref
#    PASS: Analytical Arrhenius value at 308.15 K
#    PASS: 10 K increase gives ~2x acceleration (actual: 2.00x)
#    PASS: Factor = 1.0 when E_a = 0
#
# [2] Degradation Progress & SOC Window
# ----------------------------------------
#    PASS: Degradation progress = 0 at BOL
#    PASS: Degradation progress = 1 at EOL
#    PASS: Degradation progress = 0.5 at SoH = 0.85
#    PASS: SOC_min = BOL value at deg_eff = 0
#    PASS: SOC_max = BOL value at deg_eff = 0
#    PASS: SOC_min = EOL value at deg_eff = 1
#    PASS: SOC_max = EOL value at deg_eff = 1
#    PASS: SOC_min increases with degradation
#    PASS: SOC_max decreases with degradation
#    PASS: Usable SOC window shrinks with degradation
#
# [3] Efficiency Fade
# ----------------------------------------
#    PASS: Efficiency = BOL value at deg_eff = 0
#    PASS: Efficiency = EOL value at deg_eff = 1
#    PASS: Efficiency decreases monotonically
#    PASS: Efficiency follows linear interpolation
#
# [4] Cell Temperature
# ----------------------------------------
#    PASS: T_cell = T_ambient when idle (no offset)
#    PASS: T_cell = T_ambient + T_static when idle
#    PASS: Discharge increases cell temperature
#    PASS: Temperature rise matches heat generation model
#    PASS: Lower efficiency produces more heating
#
# [5] Calendar Aging Increment
# ----------------------------------------
#    PASS: Higher temperature accelerates calendar aging
#    PASS: Higher SOC accelerates calendar aging
#    PASS: Calendar increment at T_ref matches SOC factor
#
# [6] Cycle Aging Increment (battery-side power, cap_now)
# ----------------------------------------
#    PASS: No cycle aging when idle
#    PASS: Higher power increases cycle aging
#    PASS: Cycle aging scales linearly with power
#    PASS: Higher temperature accelerates cycle aging
#    PASS: Cycle aging formula at T_ref
#    PASS: Degraded SoH (lower cap_now) increases cycle aging rate
#    PASS: Rate scales as 1/cap_now at fixed P_batt and T
#
# [7] Boundary Conditions & Edge Cases
# ----------------------------------------
#    PASS: Degradation progress clamped at 1.0 below EOL
#    PASS: Degradation progress clamped at 0.0 above BOL
#    PASS: Arrhenius factor finite at 100degC
#    PASS: Arrhenius factor large at high temperature
#    PASS: Arrhenius factor finite at -20degC
#    PASS: Arrhenius factor small at low temperature
#    PASS: Cycle aging uses absolute power
#
# [8] Cross-Function Consistency
# ----------------------------------------
#    PASS: Different activation energies produce different Arrhenius factors
#    PASS: Higher E_a gives stronger temperature dependence
#    PASS: SOC_min interpolation consistent
#    PASS: SOC_max interpolation consistent
#    PASS: Efficiency interpolation consistent
#
# [9] K_T Calibration at Rated Power P_dis
# ----------------------------------------
#    PASS: K_T is positive
#    PASS: K_T is finite
#    PASS: T_rise at P_dis equals calibrated_temp_rise_c4
#    PASS: Q_heat_ref = P_dis/eta - P_dis algebraic identity
#    PASS: Q_heat_ref > 0 (eta_BOL < 1)
#    PASS: Cell temp at P_dis = T_amb + calibrated_temp_rise_c4
#    PASS: K_T scales inversely with rated power
#
# [10] P_batt vs P_grid Regression Guard
# ----------------------------------------
#    PASS: Cycle aging at P_batt > cycle aging at P_grid (eta < 1)
#    PASS: Cycle aging ratio P_batt/P_grid = 1/eta = 1.1111
#
# [11] quality_factor Fail-Fast Guards
# ----------------------------------------
#    PASS: quality_factor=0 raises ValueError
#    PASS: quality_factor=-1 raises ValueError
#    PASS: quality_factor=0.5 doubles k_cal
#    PASS: quality_factor=0.5 doubles k_cyc
#    PASS: quality_factor=2.0 halves k_cal
#    PASS: quality_factor=2.0 halves k_cyc
#
# [12] SOC Invariant on Micro-Trajectory
# ----------------------------------------
#    PASS: SOC within logged window (tol=0.0001) at all 48 timesteps (violations: 0)
#    PASS: Logged SOC bounds well-ordered and within [0,1]
#    PASS: SOC within window during all idle hours (tol=0.0001, violations: 0)
#    PASS: cumulative_kwh is monotonically non-decreasing
#    PASS: cumulative_kwh > 0 after discharge
#    PASS: SoH is non-increasing over micro-trajectory
#    PASS: FEC is plausible after 2-day micro-trajectory: 1.7778
#
# [13] dur_hours Integer Enforcement
# ----------------------------------------
#    PASS: dur_hours is int (got int)
#    PASS: dur_hours equals rounded num_discharge_hours
#    PASS: dur_hours >= 1 (got 4)
#    PASS: Non-integer num_discharge_hours raises ValueError
#
# [14] Efficiency Bounds
# ----------------------------------------
#    PASS: eta_dis_BOL in (0,1]: 0.95
#    PASS: eta_dis_EOL in (0,1]: 0.9
#    PASS: Efficiency in (0,1] for all deg_eff in [0,1]
#    PASS: compute_cell_temperature rejects eta > 1
#    PASS: compute_cell_temperature rejects eta = 0
#
# [15] SOC Window Well-Ordering
# ----------------------------------------
#    PASS: BOL window well-ordered: [0.0500, 0.9500]
#    PASS: EOL window well-ordered: [0.2000, 0.8000]
#    PASS: SOC window well-ordered for all deg_eff in [0,1]
#    PASS: Window width always positive
#    PASS: Window width non-increasing with degradation
#
# [16] SoH Nonphysical Guard
# ----------------------------------------
#    PASS: SoH = 1 - q_cal - q_cyc at first timestep
#    PASS: SoH never exceeds 1.0 (max: 0.9999955168)
#    PASS: SoH never goes negative (min: 0.9997606847)
#    PASS: q_loss_cal always >= 0 (min: 0.0000044832)
#    PASS: q_loss_cyc always >= 0 (min: 0.0000000000)
#
# [17] Thermal Limit Edge Cases
# ----------------------------------------
#    PASS: eta ~ 1 ---> P_therm = +inf (got inf)
#    PASS: eta = 1.0 ---> P_therm = +inf (got inf)
#    PASS: eta > 1 raises ValueError in compute_thermal_limit
#    PASS: Normal eta gives finite P_therm >= 0 (got 34500.0)
#    PASS: Lower K_T (less sensitive) ---> higher thermal limit
#
# ============================================================
# PHYSICS UNIT TESTS: 93/93 passed
# All physics functions validated against analytical expectations.
# ============================================================
# Cell 6: Physics unit tests complete.
# Cell 4: Generated 219,000 hours of environment data.
#    OUTDOOR temp: -2.7degC to 46.4degC (range: 49.1degC)
#    CONTAINER temp: 18.7degC to 25.5degC (range: 6.8degC)
#       Baseline (setpoint): 22.0degC
#       Configured attenuation: 8.3%
#       Effective attenuation: 13.9%
#    Weather-adjusted base price: $14 to $128/MWh
#    Final price range: $0 to $5000/MWh
#    Spikes: 724 (0.33%), base magnitude: $100/MWh
#    Outdoor temp-price correlation: 0.123
#
#    === Calibration Check ===
#    Month  1: Mean $ 36.9 (target $ 30.0) | CV 1.22 (target 1.20)
#    Month  2: Mean $ 36.9 (target $ 28.0) | CV 1.71 (target 1.10)
#    Month  3: Mean $ 34.2 (target $ 25.0) | CV 1.37 (target 1.00)
#    Month  4: Mean $ 40.8 (target $ 30.0) | CV 1.30 (target 1.00)
#    Month  5: Mean $ 48.2 (target $ 35.0) | CV 1.26 (target 1.20)
#    Month  6: Mean $ 53.1 (target $ 40.0) | CV 1.11 (target 1.30)
#    Month  7: Mean $ 73.5 (target $ 55.0) | CV 1.26 (target 1.70)
#    Month  8: Mean $ 96.4 (target $ 65.0) | CV 1.27 (target 2.00)
#    Month  9: Mean $ 62.4 (target $ 45.0) | CV 1.15 (target 1.50)
#    Month 10: Mean $ 49.4 (target $ 35.0) | CV 1.10 (target 1.40)
#    Month 11: Mean $ 40.6 (target $ 30.0) | CV 1.20 (target 1.10)
#    Month 12: Mean $ 39.7 (target $ 32.0) | CV 1.11 (target 1.00)
#
# Cell 7: Temperature-Aware Dispatch Schedule (TwinBESS)
# ============================================================
#    Simulation horizon:    25 years (219000 hours)
#    Base dispatch window:  11:00 - 21:00
#    Random seed:           43
#
#    === Day Classification (using T_outdoor_forecast) ===
#    Hot days (CDD > 4.0):  3562 (39.0%) -> window +3h
#    Cold days (HDD > 4.0): 3580 (39.2%) -> window -1h
#    Mild days:              1983 (21.7%) -> no shift
#
#    === Dispatch Summary ===
#    Total days:            9125
#    Days w/ discharge:     9125
#
#    === Discharge Start Hour by Day Type ===
#    Hot  : mean start hour = 19.4
#    Cold : mean start hour = 15.2
#    Mild : mean start hour = 16.5
#
#    PASS: exactly one 4-hour discharge block per day
# ============================================================
# Cell 8: Discharge Diagnostics (SCHEDULE-ONLY)
#    Days: 9125, with discharge: 9125
#    Required: 4h, days with exactly 4h: 100.0%
#    Sample (first 5 days):
#       date  discharge_hours  E_out_int_kwh  frac_window
# 2025-01-01                4    4210.526316     0.935673
# 2025-01-02                4    4210.526316     0.935673
# 2025-01-03                4    4210.526316     0.935673
# 2025-01-04                4    4210.526316     0.935673
# 2025-01-05                4    4210.526316     0.935673
# Cell 9: EXPORT_YEARS = 25
# Cell 9: Single-asset simulation runner defined (EXPORT_YEARS=25).
#    FIXED: Month indexing uses simulation time, not calendar timestamps.
# Cell 10: Running fleet of 100 assets for 25 years (seed=43)...
#    10/100 | life=12.57y | SoH=0.7000 | T=28.5C
#    20/100 | life=13.55y | SoH=0.7000 | T=28.1C
#    30/100 | life=13.70y | SoH=0.7000 | T=29.2C
#    40/100 | life=12.73y | SoH=0.7000 | T=28.3C
#    50/100 | life=13.79y | SoH=0.7000 | T=28.8C
#    60/100 | life=12.91y | SoH=0.7000 | T=29.3C
#    70/100 | life=14.81y | SoH=0.7000 | T=26.8C
#    80/100 | life=15.15y | SoH=0.7000 | T=22.8C
#    90/100 | life=13.41y | SoH=0.7000 | T=25.2C
#    100/100 | life=14.46y | SoH=0.7000 | T=27.8C
# Cell 10: Done. 100 assets in 1308.4s
#    Export data: 126641 hours (14.5 years)
# Cell 11: Validation Diagnostics
# ============================================================
#
# [TEST 1] Outages Enforced
# ----------------------------------------
#    Total hours: 8760
#    Outage hours (is_valid=False): 1
#    Energy dispatched during outages: 0.0000 kWh
#    PASS: No energy flow during outage hours
#
# [TEST 2] SOC Ceiling Degrades with SoH
# ----------------------------------------
#    Day 1:   SoH=1.0000, Max SOC=0.9500, Ceiling=0.9500
#    Day 365: SoH=0.9704, Max SOC=0.9352, Ceiling=0.9352
#    Ceiling drop over year: 0.0148 (1.6%)
#    Days exceeding ceiling: 0/365
#    Days with visible reset: 100%
#    PASS: SOC respects degraded ceiling and ceiling shrinks over time
#
# [TEST 3] FEC Monotonically Increases
# ----------------------------------------
#    FEC at start: 0.00 cycles
#    FEC at end:   324.43 cycles
#    Theoretical max (no derating): 324.44 cycles
#    Achieved: 100.0% of theoretical
#    FEC decreases detected: 0
#    PASS: FEC is monotonically increasing
#
# [TEST 4] Measurement Noise Parameters Valid
# ----------------------------------------
#    sigma_soc_meas:  0.02
#    sigma_soh_meas:  0.01
#    sigma_temp_meas: 0.5
#    PASS: All noise parameters are non-negative
#    NOTE: Noise is applied at export time (Cell 12), not during simulation
#
# [TEST 5] Quality Factor Logic
# ----------------------------------------
#    Quality factor > 1.0: n=49, avg revenue=$1,743,300, avg life=14.9y
#    Quality factor < 1.0: n=51, avg revenue=$1,663,289, avg life=14.2y
#    PASS: Higher quality factor ---> longer lifespan
#
# [TEST 6] Thermal Gradient Logic
# ----------------------------------------
#    Configured gradient: 5.0 degC
#    Top rack (pos > 0.8): n=17, avg revenue=$1,511,034, avg life=13.0y
#    Bottom rack (pos < 0.2): n=20, avg revenue=$1,880,186, avg life=16.0y
#    Lifespan difference: 3.03 years
#    PASS: Bottom rack (cooler) ---> longer lifespan
#
# ============================================================
# VALIDATION SUMMARY: ALL TESTS PASSED
# ============================================================
# Cell 12: Exporting TwinBESS CSV (last asset, 14.5 years)...
# Cell 12: Export complete.
#    Output: /content/drive/MyDrive/SAGE/sage_scenario_for_twinbess.csv
#    Shape: (126641, 17)
#    Date range: 2025-01-01 00:00:00 -> 2039-06-13 16:00:00
#    Measurement noise seed: 123
#    Noise applied: σ_soc=0.02, σ_soh=0.01, σ_temp=0.5
#    FEC at end: 3366.11 cycles
#
#    === Temperature Summary ===
#    OUTDOOR (for price forecasting):
#       Range: -2.5degC to 45.9degC
#       Forecast correlation: 0.988
#       Forecast RMSE: 1.51degC
#       Price correlation: 0.123
#    CONTAINER (for degradation):
#       Range: 18.7degC to 25.5degC
#       Forecast correlation: 0.718
#       Forecast RMSE: 0.72degC
#
#    Columns: ['t_timestamp', 'Price_Forecast', 'Price_Actual', 'Temp_Ambient', 'T_amb_forecast', 'T_outdoor', 'T_outdoor_forecast', 'T_cell_SAGE_Truth', 'SOC_SAGE_Truth', 'SoH_SAGE_Truth', 'T_cell_Measured', 'SOC_Measured', 'SoH_Measured', 'Revenue', 'P_dis', 'P_ch', 'FEC']
# Cell 25: Exporting results to /content/drive/MyDrive/SAGE
#    Fleet CSV: 100 assets saved to sage_fleet_lifespans.csv
#    Lifespan range: 12.5-17.0 years
#    Exporting single-asset monthly history for asset index 0
#    Single-asset CSV: 194 months saved to sage_single_asset_trajectory.csv
#    EOL at year: 16.1
#    Final SoH: 0.700
#    Total throughput: 16,947,629 kWh
#    Fleet pickle: 100 assets + 219,000 hours env_ref saved to sage_fleet_data.pkl
#    Export trajectory: 126,641 hours (14.5 years)
#    Pickle includes: T_outdoor, T_outdoor_forecast (dual temp model)
#    Params JSON: sage_params_snapshot.json (77 keys via dataclasses.asdict())
#
# Cell 25: Export complete.
#    1. sage_fleet_lifespans.csv - fleet lifespan distribution (CSV)
#    2. sage_single_asset_trajectory.csv - single-asset degradation trajectory (CSV)
#    3. sage_fleet_data.pkl - full fleet data + 25-year environment (Pickle)
#    4. sage_params_snapshot.json - parameter snapshot (JSON)
# ============================================================
# DURATION RISK VALIDATION (Figure 1)
# ============================================================
#
# At Beginning of Life (month 0):
#   SoH:              0.9972
#   SoH_norm:         1.0000 (should be 1.0000)
#   deg_progress:     0.0000 (should be 0.0000)
#   SOC window:       [0.05, 0.95] = 0.90
#   Efficiency:       0.950
#   E_avail:          4487 kWh
#   P_energy_limited: 1066 kW
#   P_firm:           1000 kW (limiting factor: nameplate-capped)
#   E_usable:         4000 kWh
#
# At End of Life (month 193, year 16.1):
#   SoH:              0.7000
#   SoH_norm:         0.7020
#   deg_progress:     1.0000 (should be ~1.0)
#   SOC window:       [0.20, 0.80] = 0.60
#   Efficiency:       0.900
#   E_avail:          2100 kWh
#   P_energy_limited: 472 kW
#   P_firm:           472 kW (limiting factor: energy-limited)
#   E_usable:         1890 kWh
#
# ============================================================
# >>> KEY RESULT <<<
# ============================================================
#   Capacity fade:    29.8%
#   Energy fade:      52.8%
#   Gap:              22.9 percentage points
# ============================================================
#
# Energy limit first binds at month 13 (year 1.1)
#   SoH at binding:   0.9695
# ============================================================
# Exported: sage_duration_risk_data.csv (194 rows)
# Saved: figure_1a_duration_risk.png/.pdf to /content/drive/MyDrive/SAGE
# Saved: figure_1b_duration_risk_time.png/.pdf to /content/drive/MyDrive/SAGE
