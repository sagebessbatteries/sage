# %% [markdown]
# # SAGE sensitivity analysis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys

# Replace 'my_script_folder' with the actual path to your folder in Google Drive
script_path = '/content/drive/MyDrive/SAGE/Github'
sys.path.insert(0, script_path)

# %%
from sage_sensitivity_analysis import *
# Out:
# Loaded 8 parameters from sensitivity_sweeps.csv
# /content/drive/MyDrive/SAGE/Github/sage_sensitivity_analysis.py:81: RankWarning: Polyfit may be poorly conditioned
#   slope = np.polyfit(x, y, 1)[0]
# Saved: Fig_tornado_elasticity.png/pdf
#
# ...
# TABLE S7a: Parameter Sweep Definitions
# ...
# Parameter,Baseline,Sweep Values,Units
# sigma_manufacturing_quality,0.03,0.01; 0.02; 0.03; 0.05,—
# vertical_temp_gradient_C,5.0,2.0; 5.0; 8.0,°C
# beta_cal,0.6,0.5; 0.6; 0.75,—
# E_a_cal,53000.0,45000.0; 53000.0; 60000.0,J/mol
# E_a_cyc,35000.0,25000.0; 35000.0; 45000.0,J/mol
# container_baseline,26.0,18.0; 22.0; 26.0; 30.0,°C
# num_discharge_hours,4.0,2.0; 4.0; 6.0,h
# SoH_EOL,0.7,0.6; 0.7; 0.8,—
#
# ...
# TABLE S7b: Full Results
# ...
# Parameter,Value,Mean (yr),Std (yr),P10 (yr),P50 (yr),P90 (yr),Min (yr),Max (yr)
# E_a_cal,45000.0,14.54,1.07,13.12,14.52,15.78,12.54,16.93
# E_a_cal,53000.0,14.55,1.12,13.07,14.52,15.85,12.46,17.03
# E_a_cal,60000.0,14.56,1.16,13.03,14.51,15.91,12.4,17.13
# ...
