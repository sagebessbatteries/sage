# %% [markdown]
# # SAGE visualizations

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys

# Replace 'my_script_folder' with the actual path to your folder in Google Drive
script_path = '/content/drive/MyDrive/SAGE/Github'
sys.path.insert(0, script_path)

# %%
from sage_visualizations import *
# Out:
# Mounted at /content/drive
#    Loaded params with encoding: utf-8
#    Loaded 88 parameters from sage_params.csv
#    Snapshot copied to: /content/sage_cache/sage_fleet_data.pkl
# Cell 0: Loaded 100 assets + 219,000 hours env_ref from sage_fleet_data.pkl
#    Year-1 data: 126641 hours
#    Loaded 14 visualization parameters
#    Ready for VIZ cells.
# VIZ-1: Generating degradation physics plots...
#    Configured beta_cal: 0.75
# /content/drive/MyDrive/SAGE/Github/sage_visualizations.py:458: RuntimeWarning: divide by zero encountered in divide
#   stress_ratio = t_eff_years / years_valid
# ============================================================
# DEGRADATION PHYSICS VALIDATION SUMMARY
# ============================================================
#
# Visualization Parameters Used:
#    loglog_exclude_years: 0.5
#    sqrt_exclude_years: 0.1
#
# Asset 0 Trajectory:
#    Duration: 16.1 years (194 months)
#    Initial SoH: 0.9972
#    Final SoH:   0.7000
#    Total q_loss: 0.3000
#
# Aging Mechanism Split (at EOL):
#    Calendar: 0.0855 (28.5%)
#    Cycle:    0.2145 (71.5%)
#
# Exponent Validation:
#    Configured beta_cal: 0.75
#    Extracted beta_fit:  0.7188 +/- 0.0010 (95% CI)
#    Log-log R²:       0.9999
#    DEVIATION: beta_fit differs by -0.0312 from configured
#
# sqrt(t) Fit Quality:
#    Against clock time (t):     R² = 0.9445
#    Against effective time (t_eff): R² = 0.9304
#
# Stress Acceleration:
#    Mean t_eff/t_clock: 1.308x
#    -> Operating conditions are 31% more stressful than reference
#
# ============================================================
# VIZ-2: Generating thermal model plots...
# Thermal Summary (Fleet):
#    Assets reaching EOL: 100
#    Assets censored (>24 yr): 0
#    Year 1 T_cell: median=24.77°C, range=[22.41, 27.32]
#    Position gradient (Year 1): 5.00 °C/unit
#    Arrhenius effect: -0.78 yr/°C (excluding censored)
# Points being plotted on right panel: 100
# VIZ-3: Generating dispatch and electro-thermal coupling plots...
#    Note: eta_dis not in trajectory, computing from SoH using physics params
# Dispatch Summary:
#    Total dispatch hours: 21106 (16.7%)
#    Median price when dispatching: $57.86/MWh
#    Median price when idle: $31.29/MWh
#    Price premium captured: $26.57/MWh
#
# Electro-thermal Coupling (Year 1):
#    Temperature range: [21.8, 30.7] °C
#    Mean temperature: 25.4 °C
#    Max heat generation: 111.1 kW
#    SoH range: [0.7000, 1.0000]
#
# Parameters Used:
#    eta_discharge_bol: 0.95
#    eta_discharge_eol: 0.9
#    SoH_EOL: 0.7
#    efficiency_clip_min: 0.8
#    efficiency_clip_max: 0.99
# VIZ-3b: Generating Figure 4 (Fleet Revenue Divergence)...
#    Available keys in monthly history: ['monthly_soh_history', 'monthly_T_cell_mean_history', 'monthly_qcal_history', 'monthly_qcyc_history', 'monthly_cumulative_kwh_history', 'monthly_cumulative_revenue_history']
#    Using actual simulation revenue data
#    Valid assets: 100/100
# Figure 4 Summary:
#    Median lifetime revenue: $1688k
#    10-90th percentile gap: $339k (20%)
#
# Parameters Used:
#    revenue_display_start_year: 12
#
# Saved: figure_4_revenue_divergence.png/.pdf to /content/drive/MyDrive/SAGE
# VIZ-4: Generating fleet heterogeneity plots...
# Saved: figure_2_fleet_distribution.png/.pdf to /content/drive/MyDrive/SAGE
# /content/drive/MyDrive/SAGE/Github/sage_visualizations.py:1175: RuntimeWarning: Mean of empty slice
#   T_mean = np.nanmean(T_cohort, axis=0)
# Fleet Summary (100 assets):
#    Quality factor: mean=0.998, std=0.021
#    Vertical position: mean=0.502, std=0.273
#    Lifespan: mean=14.6y, std=1.1y, range=[12.5, 17.0]
#
# Weibull Fit:
#    Shape (beta): 13.93  (beta>1 = wear-out failures)
#    Scale (eta): 15.07 years
#
# Stressor Effects on Lifespan:
#    Temperature: R2 = 0.911 (r = -0.954)
#    Quality:     R2 = 0.131 (r = 0.362)
#    Combined:    R2 ~ 1.000 (approximate, assumes independence)
#
# Cohort Sizes:
#    High quality (>75.0%ile): 25 assets
#    Low quality (<25.0%ile): 25 assets
#    Top rack (>0.75): 23 assets
#    Bottom rack (<0.25): 22 assets
#
# Parameters Used:
#    cohort_high_pct: 75.0
#    cohort_low_pct: 25.0
#    position_high: 0.75
#    position_low: 0.25
# VIZ-5: Generating Arrhenius activation energy validation plots...
# ============================================================
# ARRHENIUS ACTIVATION ENERGY VALIDATION
# ============================================================
#
# Temperature range: 22.4C to 27.3C
# Assets analyzed: 100
#
# CALENDAR AGING (E_a_cal):
#    Configured:  53.0 kJ/mol
#    Extracted:   52.9 kJ/mol
#    Error:       -0.1%
#    Status:      VALIDATED (within 10%)
#
# CYCLE AGING (E_a_cyc):
#    Configured:  35.0 kJ/mol
#    Extracted:   35.4 kJ/mol
#    Error:       +1.2%
#    Status:      VALIDATED (within 15%)
#
# ============================================================
# VIZ-6: Generating SOC and energy plots...
# SOC and Energy Summary:
#    BOL window: [0.05, 0.95] = 0.90
#    EOL window: [0.20, 0.80] = 0.60
#    BOL usable energy: 4500 kWh
#    EOL usable energy: 4500 kWh
#    Year-1 SOC range: [0.064, 0.950]
# VIZ-7: Generating environment validation plots...
#    Using 219,000 hours (25.0 years) for validation
#    Spike threshold: 10.0x monthly mean
#    Spikes detected: 112
# Environment Validation Summary:
#    Data: 219,000 hours (25.0 years)
#    Hours per month: 16,944 - 18,600
#    Price calibration:
#       Mean price MAE: $13.51/MWh
#    Fat-tail analysis (prices > 10x monthly mean):
#       Number of extreme price events: 112
#       Prices at ceiling ($5000): 3
#    Tail index:
#       Pareto input: 1.40
#       Effective (Hill): 1.54
# VIZ-8: Generating sensitivity analysis plots...
# Sensitivity Analysis Summary (Multivariate Regression):
#    Model: Lifespan = 0.67 + -3.81*Position + 15.83*Quality
#    Position effect (0->1): -3.81 years
#    Quality effect (0.94->1.05): +1.67 years
#    Residual-Quality correlation: r = -0.0000 (should be ~0)
#    Interpretation:
#       - Top-of-rack modules lose 3.8 years vs bottom
#       - High-quality modules gain 1.7 years vs low-quality
#
# Parameters Used:
#    lifespan_cap: 40.0
